# %%
import numpy as np
import pandas as pd

def readFile(fileName):
  with open('../content/'+fileName, 'r') as f:
    reader = np.genfromtxt(f, delimiter=',')
    data = np.array(reader)
    if set_id >= 0:
        data = insertSetID(data, set_id)
    return data
      
    






clev_file = readFile('processed.cleveland.data')
#hung_file = readFile('processed.hungarian.data')
#Eswitz_file = readFile('processed.switzerland.data')
#Eva_file = readFile('processed.va.data')


clev_file
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-3f99a5013fcc> in <module>()
#      17
#      18
# ---> 19 clev_file = readFile('processed.cleveland.data')
#      20 #hung_file = readFile('processed.hungarian.data')
#      21 #Eswitz_file = readFile('processed.switzerland.data')
#
# <ipython-input-3-3f99a5013fcc> in readFile(fileName)
#       4 def readFile(fileName):
#       5   with open('../content/'+fileName, 'r') as f:
# ----> 6     reader = np.genfromtxt(f, delimiter=',')
#       7     data = np.array(reader)
#       8     if set_id >= 0:
#
# ...
